# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
filename = "My Personality - Sheet1.csv"
df = pd.read_csv(filename, header = 1)
df.head()
# Out:
#    Date yymmdd  Extravert  Intuitive  Thinking  Judging  Assertive
# 0       210928       0.85       0.74      0.41     0.57       0.37
# 1       230430       0.73       0.72      0.48     0.82       0.53
# 2       230918       0.54       0.62      0.64     0.83       0.51
# 3       230926       0.60       0.51      0.55     0.79       0.69
# 4       240807       0.68       0.67      0.51     0.78       0.65

# %%
df
# Out:
#    Date yymmdd  Extravert  Intuitive  Thinking  Judging  Assertive
# 0       210928       0.85       0.74      0.41     0.57       0.37
# 1       230430       0.73       0.72      0.48     0.82       0.53
# 2       230918       0.54       0.62      0.64     0.83       0.51
# 3       230926       0.60       0.51      0.55     0.79       0.69
# 4       240807       0.68       0.67      0.51     0.78       0.65

# %%
df.columns
# Out:
# Index(['Date yymmdd', 'Extravert', 'Intuitive', 'Thinking', 'Judging',
#        'Assertive'],
#       dtype='object')

# %%
# Choose columns for x and y axes
x_column = 'Date yymmdd'  # Replace with actual column name
y_column1 = 'Extravert'  # Replace with actual column name
y_column2 = 'Intuitive'  # Replace with actual column name
y_column3 = 'Thinking'  # Replace with actual column name
y_column4 = 'Judging'  # Replace with actual column name
y_column5 = 'Assertive'  # Replace with actual column name

# Create line plot
plt.plot(df[x_column], df[y_column1], marker = 'o', linestyle = '-')
plt.title('Line Plot of Extravert')
plt.xlabel(x_column)
plt.xticks(df[x_column], rotation=90, fontsize=5)
plt.ylabel(y_column1)
plt.show()

# Create line plot
plt.plot(df[x_column], df[y_column2], marker = 'o', linestyle = '-')
plt.title('Line Plot of Intuitive')
plt.xlabel(x_column)
plt.xticks(df[x_column], rotation=90, fontsize=5)
plt.ylabel(y_column2)
plt.show()

# Create line plot
plt.plot(df[x_column], df[y_column3], marker = 'o', linestyle = '-')
plt.title('Line Plot of Thinking')
plt.xlabel(x_column)
plt.xticks(df[x_column], rotation=90, fontsize=5)
plt.ylabel(y_column3)
plt.show()

# Create line plot
plt.plot(df[x_column], df[y_column4], marker = 'o', linestyle = '-')
plt.title('Line Plot of Judging')
plt.xlabel(x_column)
plt.xticks(df[x_column], rotation=90, fontsize=5)
plt.ylabel(y_column4)
plt.show()

# Create line plot
plt.plot(df[x_column], df[y_column5], marker = 'o', linestyle = '-')
plt.title('Line Plot of Assertive')
plt.xlabel(x_column)
plt.xticks(df[x_column], rotation=90, fontsize=5)
plt.ylabel(y_column5)
plt.show()

# %%
# Create line plot
plt.plot(df[x_column], df[y_column1], marker = 'o', linestyle = '-')
plt.plot(df[x_column], df[y_column2], marker = 'o', linestyle = '-')
plt.plot(df[x_column], df[y_column3], marker = 'o', linestyle = '-')
plt.plot(df[x_column], df[y_column4], marker = 'o', linestyle = '-')
plt.plot(df[x_column], df[y_column5], marker = 'o', linestyle = '-')
plt.title('Line Plot of Extravert')
plt.xlabel(x_column)
plt.xticks(df[x_column], rotation=90, fontsize=5)
plt.ylabel(y_column1)
legend_labels = [y_column1, y_column2, y_column3, y_column4, y_column5]
plt.legend(legend_labels)
plt.show()
